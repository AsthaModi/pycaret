# %% [markdown]
# <a href="https://colab.research.google.com/github/AsthaModi/pycaret/blob/main/pycaret2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pycaret
# Out:
# ...
#   Using cached pycaret-3.3.2-py3-none-any.whl.metadata (17 kB)
# ...
#   Using cached scipy-1.11.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
# ...
#   Using cached joblib-1.3.2-py3-none-any.whl.metadata (5.4 kB)
# ...
#   Using cached scikit_learn-1.5.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# ...
#   Using cached pyod-2.0.2.tar.gz (165 kB)
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached category_encoders-2.6.3-py2.py3-none-any.whl.metadata (8.0 kB)
# ...
#   Using cached deprecation-2.1.0-py2.py3-none-any.whl.metadata (4.6 kB)
# ...
#   Using cached xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# ...
#   Using cached scikit_plot-0.3.7-py3-none-any.whl.metadata (7.1 kB)
# ...
#   Using cached kaleido-0.2.1-py2.py3-none-manylinux1_x86_64.whl.metadata (15 kB)
# ...
#   Using cached schemdraw-0.15-py3-none-any.whl.metadata (2.2 kB)
# ...
#   Using cached plotly_resampler-0.10.0-py3-none-any.whl.metadata (13 kB)
# ...

# %%
from pycaret.datasets import get_data

# %%
all_datasets = get_data('index')
# Out:
#                              Dataset    Data Types  \
# 0                            anomaly  Multivariate
# 1                             france  Multivariate
# 2                            germany  Multivariate
# 3                               bank  Multivariate
# 4                              blood  Multivariate
# 5                             cancer  Multivariate
# 6                             credit  Multivariate
# 7                           diabetes  Multivariate
# 8                    electrical_grid  Multivariate
# 9                           employee  Multivariate
# 10                             heart  Multivariate
# 11                     heart_disease  Multivariate
# 12                         hepatitis  Multivariate
# 13                            income  Multivariate
# 14                             juice  Multivariate
# 15                               nba  Multivariate
# 16                              wine  Multivariate
# ...

# %%
dataset = get_data('employee')
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  promotion_last_5years department  \
# 0                   3              0                      0      sales
# 1                   6              0                      0      sales
# 2                   4              0                      0      sales
# 3                   5              0                      0      sales
# 4                   3              0                      0      sales
#
#    salary  left
# 0     low     1
# 1  medium     1
# 2  medium     1
# ...

# %%
dataset.shape
# Out:
# (14999, 10)

# %%
dataset.columns
# Out:
# Index(['satisfaction_level', 'last_evaluation', 'number_project',
#        'average_montly_hours', 'time_spend_company', 'Work_accident',
#        'promotion_last_5years', 'department', 'salary', 'left'],
#       dtype='object')

# %%
# Use for training the data
data = dataset.sample(frac = 0.95, random_state = 189)

# %%
data.shape
# Out:
# (14249, 10)

# %%
# Test data
testData = dataset.drop(data.index)

# %%
testData.shape
# Out:
# (750, 10)

# %%
data.head()
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 13775                0.66             0.50               3
# 4053                 0.92             0.67               4
# 9222                 0.92             0.94               3
# 3652                 0.85             0.63               3
# 2194                 0.83             0.65               4
#
#        average_montly_hours  time_spend_company  Work_accident  \
# 13775                   139                  10              1
# 4053                    161                   4              1
# 9222                    234                   2              1
# 3652                    167                   3              0
# 2194                    162                   3              0
#
#        promotion_last_5years   department  salary  left
# 13775                      0        sales     low     0
# 4053                       0    marketing     low     0
# 9222                       0           IT  medium     0
# ...

# %%
data.reset_index(inplace = True, drop = True)

# %%
data.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.66             0.50               3                   139
# 1                0.92             0.67               4                   161
# 2                0.92             0.94               3                   234
# 3                0.85             0.63               3                   167
# 4                0.83             0.65               4                   162
#
#    time_spend_company  Work_accident  promotion_last_5years   department  \
# 0                  10              1                      0        sales
# 1                   4              1                      0    marketing
# 2                   2              1                      0           IT
# 3                   3              0                      0  product_mng
# 4                   3              0                      0    technical
#
#    salary  left
# 0     low     0
# 1     low     0
# ...

# %%
testData.head()
# Out:
#      satisfaction_level  last_evaluation  number_project  \
# 13                 0.41             0.55               2
# 21                 0.38             0.55               2
# 50                 0.13             0.78               6
# 88                 0.37             0.57               2
# 100                0.38             0.52               2
#
#      average_montly_hours  time_spend_company  Work_accident  \
# 13                    148                   3              0
# 21                    147                   3              0
# 50                    152                   2              0
# 88                    130                   3              0
# 100                   154                   3              0
#
#      promotion_last_5years department  salary  left
# 13                       0      sales     low     1
# 21                       0      sales     low     1
# 50                       0    support     low     1
# ...

# %%
testData.reset_index(inplace = True, drop = True)

# %%
testData.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.41             0.55               2                   148
# 1                0.38             0.55               2                   147
# 2                0.13             0.78               6                   152
# 3                0.37             0.57               2                   130
# 4                0.38             0.52               2                   154
#
#    time_spend_company  Work_accident  promotion_last_5years department  \
# 0                   3              0                      0      sales
# 1                   3              0                      0      sales
# 2                   2              0                      0    support
# 3                   3              0                      0      sales
# 4                   3              0                      0      sales
#
#    salary  left
# 0     low     1
# 1     low     1
# 2     low     1
# ...

# %%
print('Data for training : ' + str(data.shape))
print('Data for testing : ' + str(testData.shape))
# Out:
# Data for training : (14249, 10)
# Data for testing : (750, 10)

# %%
from pycaret.classification import *

# %%
clf01 = setup(data = data, target='left', feature_selection = True,session_id=123)
# Out:
# [LightGBM] [Info] Number of positive: 2376, number of negative: 7598
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003506 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 421
# [LightGBM] [Info] Number of data points in the train set: 9974, number of used features: 20
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.238219 -> initscore=-1.162467
# [LightGBM] [Info] Start training from score -1.162467
# <style type="text/css">
# #T_16ce9_row9_col1, #T_16ce9_row15_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_16ce9" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_16ce9_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_16ce9_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
# ...

# %%
bestModel = compare_models()
# Out:
# <style type="text/css">
# #T_31795 th {
#   text-align: left;
# }
# ...

# %%
print(bestModel)
# Out:
# LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#                importance_type='split', learning_rate=0.1, max_depth=-1,
#                min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#                n_estimators=100, n_jobs=-1, num_leaves=31, objective=None,
#                random_state=123, reg_alpha=0.0, reg_lambda=0.0, subsample=1.0,
#                subsample_for_bin=200000, subsample_freq=0)

# %%
models()
# Out:
#                                      Name  \
# ID
# lr                    Logistic Regression
# knn                K Neighbors Classifier
# nb                            Naive Bayes
# dt               Decision Tree Classifier
# svm                   SVM - Linear Kernel
# rbfsvm                SVM - Radial Kernel
# gpc           Gaussian Process Classifier
# mlp                        MLP Classifier
# ridge                    Ridge Classifier
# rf               Random Forest Classifier
# qda       Quadratic Discriminant Analysis
# ada                  Ada Boost Classifier
# gbc          Gradient Boosting Classifier
# lda          Linear Discriminant Analysis
# et                 Extra Trees Classifier
# xgboost         Extreme Gradient Boosting
# lightgbm  Light Gradient Boosting Machine
# dummy                    Dummy Classifier
#
#                                                   Reference  Turbo
# ID
# lr        sklearn.linear_model._logistic.LogisticRegression   True
# ...

# %%
lightgbm = create_model("lightgbm")
# Out:
# <style type="text/css">
# #T_f1c6e_row10_col0, #T_f1c6e_row10_col1, #T_f1c6e_row10_col2, #T_f1c6e_row10_col3, #T_f1c6e_row10_col4, #T_f1c6e_row10_col5, #T_f1c6e_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_f1c6e" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f1c6e_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_f1c6e_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_f1c6e_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_f1c6e_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_f1c6e_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_f1c6e_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_f1c6e_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
# ...

# %%
print(lightgbm.feature_name_)
print(lightgbm.feature_importances_)
# Out:
# ['average_montly_hours']
# [3000]

# %%
tune_gbm = tune_model(lightgbm)
print(tune_gbm)
# Out:
# <style type="text/css">
# #T_79be9_row10_col0, #T_79be9_row10_col1, #T_79be9_row10_col2, #T_79be9_row10_col3, #T_79be9_row10_col4, #T_79be9_row10_col5, #T_79be9_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_79be9" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_79be9_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_79be9_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_79be9_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_79be9_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_79be9_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_79be9_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_79be9_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
# ...

# %%
yPred = predict_model(tune_gbm, data = testData)
# Out:
# <style type="text/css">
# </style>
# <table id="T_aecf6" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_aecf6_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_aecf6_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_aecf6_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_aecf6_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_aecf6_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_aecf6_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_aecf6_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_aecf6_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_aecf6_level0_row0" class="row_heading level0 row0" >0</th>
# ...
